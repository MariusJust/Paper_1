# %%
from tensorflow.keras.backend import sigmoid
def swish(x, beta=1):
    """
    Swish activation function.

    ARGUMENTS
        * x:    input variable.
        * beta: hyperparameter of the Swish activation function.

    Returns
        * Swish activation function applied to x.
    """

    return x * sigmoid(beta * x)
# Out:
# 2025-06-24 09:16:32.363414: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-24 09:16:32.379845: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 09:16:32.515219: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-24 09:16:32.711229: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# Example usage of the Swish activation function

import numpy as np
import matplotlib.pyplot as plt

input_vector =np.linspace(-10, 10, 100) 
output= [swish(x, beta=1) for x in input_vector]

plt.plot(input_vector, output)
plt.title('Swish Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid()
plt.show()

#write as pdf
from matplotlib.backends.backend_pdf import PdfPages
with PdfPages('swish_activation_function.pdf') as pdf:
    plt.plot(input_vector, output)
    plt.title('Swish Activation Function')
    plt.xlabel('Input')
    plt.ylabel('Output')
    plt.grid()
    pdf.savefig()  # saves the current figure into a pdf page
    plt.close()  # close the figure to free memory

# %%
#show the sigmoid function
plt.plot(input_vector, sigmoid(input_vector))
plt.title('Sigmoid Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid()
plt.show()

# %%
# #plot the swish and sigmoid functions next to each other
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.plot(input_vector, output)
# plt.title('Swish Activation Function')
# plt.xlabel('Input')
# plt.ylabel('Output')
# plt.grid()
# plt.subplot(1, 2, 2)
# plt.plot(input_vector, sigmoid(input_vector))
# plt.title('Sigmoid Function')
# plt.xlabel('Input')
# plt.ylabel('Output')
# plt.grid()
# plt.tight_layout()
# plt.show()

#save the swish and sigmoid functions to a pdf
with PdfPages('swish_and_sigmoid_functions.pdf') as pdf:
    plt.subplot(1, 2, 1)
    plt.plot(input_vector, output)
    plt.title('Swish')
    plt.xlabel('Input')
    plt.ylabel('Output')
    plt.grid()
    
    plt.subplot(1, 2, 2)
    plt.plot(input_vector, sigmoid(input_vector))
    plt.title('Sigmoid')
    plt.xlabel('Input')
    plt.grid()
    pdf.savefig()  # saves the current figure into a pdf page
    plt.close()  # close the figure to free memory
